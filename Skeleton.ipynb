# %%
import cv2
import numpy as np

# %%
img = cv2.imread('Images/caribbean-plate.jpg',0)
size = np.size(img)
skel = np.zeros(img.shape,np.uint8)

# %%
ret,img = cv2.threshold(img,127,255,0)
element = cv2.getStructuringElement(cv2.MORPH_CROSS,(3,3))
done = False

while(not done):
    eroded = cv2.erode(img,element)
    temp = cv2.dilate(eroded,element)
    temp = cv2.subtract(img,temp)
    skel = cv2.bitwise_or(skel,temp)
    img = eroded.copy()

    zeros = size - cv2.countNonZero(img)
    if zeros==size:
        done = True

cv2.imshow("skel",skel)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# QObject::moveToThread: Current thread (0x56306bbd9170) is not the object's thread (0x56306bcc2a90).
# Cannot move to target thread (0x56306bbd9170)
#
# QObject::moveToThread: Current thread (0x56306bbd9170) is not the object's thread (0x56306bcc2a90).
# Cannot move to target thread (0x56306bbd9170)
#
# QObject::moveToThread: Current thread (0x56306bbd9170) is not the object's thread (0x56306bcc2a90).
# Cannot move to target thread (0x56306bbd9170)
#
# QObject::moveToThread: Current thread (0x56306bbd9170) is not the object's thread (0x56306bcc2a90).
# Cannot move to target thread (0x56306bbd9170)
#
# QObject::moveToThread: Current thread (0x56306bbd9170) is not the object's thread (0x56306bcc2a90).
# Cannot move to target thread (0x56306bbd9170)
#
# QObject::moveToThread: Current thread (0x56306bbd9170) is not the object's thread (0x56306bcc2a90).
# Cannot move to target thread (0x56306bbd9170)
#
# ...

# %% [markdown]
# [Skeletonization](http://opencvpython.blogspot.com/2012/05/skeletonization-using-opencv-python.html)

# %%
#using OpenCV
img = cv2.imread('Images/caribbean-plate.jpg',0)
thinned = cv2.ximgproc.thinning(cv2.cvtColor(img, cv2.COLOR_RGB2GRAY))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [4], in <cell line: 3>()
#       1 #using OpenCV
#       2 img = cv2.imread('Images/caribbean-plate.jpg',0)
# ----> 3 thinned = cv2.ximgproc.thinning(cv2.cvtColor(img, cv2.COLOR_RGB2GRAY))
#
# AttributeError: module 'cv2' has no attribute 'ximgproc'
